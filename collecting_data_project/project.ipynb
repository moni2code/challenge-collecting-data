# %%
import requests as r
from bs4 import BeautifulSoup

root_url = "https://www.immoweb.be/en"
#search_url = "https://www.immoweb.be/en/classified/house/for-sale/libin/6890/10657263"
req = r.get(root_url)
content = req.content
#print(req.status_code,content)
soup = BeautifulSoup(content, "html")
#print(soup.prettify())

# %% [markdown]
# ##div tag  class classified

# %%
for tag in soup.find_all("a"):
    print(tag.get("href"))
# Out:
# /en
#
# https://www.immoweb.be/en/search/apartment/for-sale
# https://www.immoweb.be/en/search/house/for-sale
# https://www.immoweb.be/en/search/house-and-apartment/for-sale
# https://www.immoweb.be/en/search/new-real-estate-project-apartments/for-sale
# https://www.immoweb.be/en/search/new-real-estate-project-houses/for-sale
# https://www.immoweb.be/en/search/project-construction-houses/for-sale
# https://www.immoweb.be/en/advanced-search
# https://www.immoweb.be/en/advanced-search/house/for-sale
# https://www.immoweb.be/en/map
# https://www.immoweb.be/en/search/house/for-sale?hasVirtualTourOr360=1
#
# https://www.immoweb.be/en/search/apartment/for-rent
# https://www.immoweb.be/en/search/house/for-rent
# https://www.immoweb.be/en/search/house-and-apartment/for-rent
# https://www.immoweb.be/en/search/kot/for-rent
# https://www.immoweb.be/en/search/business/for-rent
# https://www.immoweb.be/en/advanced-search
# https://www.immoweb.be/en/advanced-search/house/for-rent
# ...
